# %%
df= pd.read_csv("/Users/shensakura/Desktop/Stats 170A/project/STATS-170A-Group/Data_final/all_neighbors_zip.csv")

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
  
# Reads 'Youtube04-Eminem.csv' file 
df = pd.read_csv("/Users/shensakura/Desktop/Stats 170A/project/STATS-170A-Group/Data_final/all_neighbors_zip.csv")
comment_words = ''
for x in df['tags']:
    if type(x)!= float:
        x= x[1:-1].replace("'","").split(", ")
        comment_words += " ".join(x)+" "

wordcloud = WordCloud(width = 3000, height = 1600,
                background_color ='white',
                min_font_size = 10).generate(comment_words)
  
# plot the WordCloud image                       
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad = 0)
plt.savefig('word_cloud.png')
plt.show()

# %%
import pandas as pd

# %%
comment_words=''
for x in df['tags']:
    if type(x) != float:
        print(x[1:-1].replace("'","").split(", "))
# Out:
# ['Quiet', 'Rural', 'Safe', 'Dog Friendly', 'Family Friendly', 'Peaceful', 'Lake', 'Nature', 'Neighbors', 'Nice']
# ['Safe', 'Peaceful', 'Quiet', 'Freeway Access', 'Open', 'Privacy', 'Rural', 'Beautiful', 'Nature', 'Trees']
# ['Peaceful', 'Friendly', 'Dog Friendly', 'Open', 'Privacy', 'Quiet', 'Rural', 'Walking', 'Atmosphere', 'Beautiful']
# ['Peaceful', 'Quiet', 'Rural', 'Privacy', 'Family Friendly', 'Friendly', 'Open', 'Beautiful', 'Dog Friendly', 'Large']
# ['Peaceful', 'Rural', 'Pleasant', 'Dog Friendly', 'Neighbors', 'Quiet', 'Freeway Access', 'Nature', 'Open', 'Privacy']
# ['Peaceful', 'Atmosphere', 'Family Friendly', 'Friendly', 'Open', 'Quiet', 'Houses', 'Community', 'Dog Friendly', 'Large']
# ['Peaceful', 'Quiet', 'Beautiful', 'Rural', 'Nature', 'Dog Friendly', 'Wildlife', 'Friendly', 'Safe', 'Family Friendly']
# ['Rural', 'Peaceful', 'Dog Friendly', 'Friendly', 'Nature', 'Hiking', 'Open', 'Clean', 'Family Friendly', 'Hills']
# ...

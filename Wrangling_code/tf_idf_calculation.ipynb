# %%
import matplotlib.pyplot as plt
from matplotlib import colors
from sklearn.neighbors import KernelDensity
import matplotlib as mpl
import matplotlib.gridspec as grid_spec
import pandas as pd
import seaborn as sns
import numpy as np
from numpy.polynomial.polynomial import polyfit

from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import cluster, datasets

# %%
neighbor = pd.read_csv("../Data_final/all_neighbors_zip.csv")
neighbor
# Out:
#           city_name                                     city_url  \
# 0            Acampo        https://nextdoor.com/city/acampo--ca/
# 1            Acampo        https://nextdoor.com/city/acampo--ca/
# 2            Acampo        https://nextdoor.com/city/acampo--ca/
# 3            Acampo        https://nextdoor.com/city/acampo--ca/
# 4            Acampo        https://nextdoor.com/city/acampo--ca/
# ...             ...                                          ...
# 17901  Yucca Valley  https://nextdoor.com/city/yucca-valley--ca/
# 17902  Yucca Valley  https://nextdoor.com/city/yucca-valley--ca/
# 17903  Yucca Valley  https://nextdoor.com/city/yucca-valley--ca/
# 17904  Yucca Valley  https://nextdoor.com/city/yucca-valley--ca/
# 17905  Yucca Valley  https://nextdoor.com/city/yucca-valley--ca/
#
#        neighborhood_name                                   neighborhood_url  \
# 0                 Acampo  https://nextdoor.com/neighborhood/acampoacampo...
# ...

# %%
neighbor.dropna(subset=['zip_code'], inplace = True)
neighbor.head(30)
# Out:
#        city_name                                     city_url  \
# 0         Acampo        https://nextdoor.com/city/acampo--ca/
# 1         Acampo        https://nextdoor.com/city/acampo--ca/
# 2         Acampo        https://nextdoor.com/city/acampo--ca/
# 3         Acampo        https://nextdoor.com/city/acampo--ca/
# 5         Acampo        https://nextdoor.com/city/acampo--ca/
# 6         Acampo        https://nextdoor.com/city/acampo--ca/
# 7         Acampo        https://nextdoor.com/city/acampo--ca/
# 8          Acton         https://nextdoor.com/city/acton--ca/
# 9          Acton         https://nextdoor.com/city/acton--ca/
# 10      Adelanto      https://nextdoor.com/city/adelanto--ca/
# 11      Adelanto      https://nextdoor.com/city/adelanto--ca/
# 12      Adelanto      https://nextdoor.com/city/adelanto--ca/
# 13      Adelanto      https://nextdoor.com/city/adelanto--ca/
# 14      Adelanto      https://nextdoor.com/city/adelanto--ca/
# ...

# %%
##neighbor.astype({'zip_code': int}).dtypes
##neighbor.astype({'zip_code': str}).dtypes
neighbor['zip_code'] = pd.to_numeric(neighbor['zip_code'], downcast='integer')
neighbor.astype({'tags': list}).dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-fe233b06f303> in <module>
#       2 ##neighbor.astype({'zip_code': str}).dtypes
#       3 neighbor['zip_code'] = pd.to_numeric(neighbor['zip_code'], downcast='integer')
# ----> 4 neighbor.astype({'tags': list}).dtypes
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5860                 if col_name in dtype:
#    5861                     results.append(
# -> 5862                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5863                     )
#    5864                 else:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
# ...

# %%
neighbor

# %%
neighbor_tags = neighbor.groupby('zip_code').agg({'tags': 'sum'})

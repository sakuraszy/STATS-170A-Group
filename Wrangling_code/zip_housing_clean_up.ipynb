# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import pandas as pd
import seaborn as sns
import numpy as np

from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import cluster, datasets

# %%
housing = pd.read_csv("../Modified_data/zip_housing.csv")

# %%
housing
# Out:
#        property_id      prop_type  year_built is_new_construction  beds  \
# 0      O2889402305   multi_family      1906.0                   f   NaN
# 1      O1305476579  single_family      1913.0                   f   3.0
# 2      O9299703972   multi_family      1938.0                   f   NaN
# 3      O2866856410  single_family      1905.0                   f   4.0
# 4      O2823776981          condo      1912.0                   f   5.0
# ...            ...            ...         ...                 ...   ...
# 98073  O1392454616  single_family      2006.0                   f   3.0
# 98074  O2959173930            NaN         NaN                   f   NaN
# 98075  O1290952370  single_family      1977.0                   f   3.0
# 98076  O1523744489  single_family      1984.0                   f   4.0
# 98077  O2996591813         mobile         NaN                   f   NaN
#
#        baths_full  baths_half  garage   price  lot_size  building_size  \
# 0             NaN         NaN     3.0  570000    7057.0         1756.0
# 1             1.0         1.0     1.0  470000    5721.0         1030.0
# 2             NaN         NaN     NaN  830000    5495.0         2503.0
# 3             2.0         NaN     NaN  400000    5387.0         1248.0
# 4             2.0         NaN     NaN  659000    5667.0         1897.0
# ...           ...         ...     ...     ...       ...            ...
# 98073         2.0         1.0     NaN  275000    2614.0         1430.0
# 98074         NaN         NaN     NaN  899000       NaN            NaN
# 98075         2.0         NaN     5.0  483500   89734.0         2552.0
# 98076         3.0         NaN     4.0  345000   87120.0         2040.0
# 98077         NaN         NaN     NaN  105000  120661.0            0.0
#
#                         line  \
# 0          6375 Converse Ave
# 1              7916 Alix Ave
# 2             1222 E 78th St
# 3             1659 E 70th St
# 4             1364 E 58th Pl
# ...                      ...
# 98073      2365 LA Villa Way
# 98074  13450 Mitchellinda Dr
# 98075         19287 Roxie Ln
# 98076       13143 Tamera Way
# 98077      20034 Parocast Rd
#
#                                            neighborhoods         city  \
# 0                        ['Florence-Graham', 'South LA']  Los Angeles
# 1                        ['Florence-Graham', 'South LA']  Los Angeles
# 2                                           ['South LA']  Los Angeles
# 3                                           ['South LA']  Los Angeles
# 4                                           ['South LA']  Los Angeles
# ...                                                  ...          ...
# 98073  ['Northeast Redding', 'The Villages at Shasta ...      Redding
# 98074                                                NaN      Redding
# 98075                                                NaN      Redding
# 98076                                                NaN      Redding
# 98077                                                NaN      Redding
#
#             county state_code  postal_code
# 0      Los Angeles         CA        90001
# 1      Los Angeles         CA        90001
# 2      Los Angeles         CA        90001
# 3      Los Angeles         CA        90001
# 4      Los Angeles         CA        90001
# ...            ...        ...          ...
# 98073       Shasta         CA        96003
# 98074       Shasta         CA        96003
# 98075       Shasta         CA        96003
# 98076       Shasta         CA        96003
# 98077       Shasta         CA        96003
#
# [98078 rows x 17 columns]

# %%
housing[['baths_half']] = housing[['baths_half']].fillna(0)
housing
# Out:
#        property_id      prop_type  year_built is_new_construction  beds  \
# 0      O2889402305   multi_family      1906.0                   f   NaN
# 1      O1305476579  single_family      1913.0                   f   3.0
# 2      O9299703972   multi_family      1938.0                   f   NaN
# 3      O2866856410  single_family      1905.0                   f   4.0
# 4      O2823776981          condo      1912.0                   f   5.0
# ...            ...            ...         ...                 ...   ...
# 98073  O1392454616  single_family      2006.0                   f   3.0
# 98074  O2959173930            NaN         NaN                   f   NaN
# 98075  O1290952370  single_family      1977.0                   f   3.0
# 98076  O1523744489  single_family      1984.0                   f   4.0
# 98077  O2996591813         mobile         NaN                   f   NaN
#
#        baths_full  baths_half  garage   price  lot_size  building_size  \
# 0             NaN         0.0     3.0  570000    7057.0         1756.0
# 1             1.0         1.0     1.0  470000    5721.0         1030.0
# 2             NaN         0.0     NaN  830000    5495.0         2503.0
# 3             2.0         0.0     NaN  400000    5387.0         1248.0
# 4             2.0         0.0     NaN  659000    5667.0         1897.0
# ...           ...         ...     ...     ...       ...            ...
# 98073         2.0         1.0     NaN  275000    2614.0         1430.0
# 98074         NaN         0.0     NaN  899000       NaN            NaN
# 98075         2.0         0.0     5.0  483500   89734.0         2552.0
# 98076         3.0         0.0     4.0  345000   87120.0         2040.0
# 98077         NaN         0.0     NaN  105000  120661.0            0.0
#
#                         line  \
# 0          6375 Converse Ave
# 1              7916 Alix Ave
# 2             1222 E 78th St
# 3             1659 E 70th St
# 4             1364 E 58th Pl
# ...                      ...
# 98073      2365 LA Villa Way
# 98074  13450 Mitchellinda Dr
# 98075         19287 Roxie Ln
# 98076       13143 Tamera Way
# 98077      20034 Parocast Rd
#
#                                            neighborhoods         city  \
# 0                        ['Florence-Graham', 'South LA']  Los Angeles
# 1                        ['Florence-Graham', 'South LA']  Los Angeles
# 2                                           ['South LA']  Los Angeles
# 3                                           ['South LA']  Los Angeles
# 4                                           ['South LA']  Los Angeles
# ...                                                  ...          ...
# 98073  ['Northeast Redding', 'The Villages at Shasta ...      Redding
# 98074                                                NaN      Redding
# 98075                                                NaN      Redding
# 98076                                                NaN      Redding
# 98077                                                NaN      Redding
#
#             county state_code  postal_code
# 0      Los Angeles         CA        90001
# 1      Los Angeles         CA        90001
# 2      Los Angeles         CA        90001
# 3      Los Angeles         CA        90001
# 4      Los Angeles         CA        90001
# ...            ...        ...          ...
# 98073       Shasta         CA        96003
# 98074       Shasta         CA        96003
# 98075       Shasta         CA        96003
# 98076       Shasta         CA        96003
# 98077       Shasta         CA        96003
#
# [98078 rows x 17 columns]

# %%
housing[['baths_full']] = housing[["baths_full"]].fillna(housing.mean()).astype({"baths_full": int})
housing['baths'] = housing['baths_full'] + housing['baths_half']*0.5
housing
# Out:
#        property_id      prop_type  year_built is_new_construction  beds  \
# 0      O2889402305   multi_family      1906.0                   f   NaN
# 1      O1305476579  single_family      1913.0                   f   3.0
# 2      O9299703972   multi_family      1938.0                   f   NaN
# 3      O2866856410  single_family      1905.0                   f   4.0
# 4      O2823776981          condo      1912.0                   f   5.0
# ...            ...            ...         ...                 ...   ...
# 98073  O1392454616  single_family      2006.0                   f   3.0
# 98074  O2959173930            NaN         NaN                   f   NaN
# 98075  O1290952370  single_family      1977.0                   f   3.0
# 98076  O1523744489  single_family      1984.0                   f   4.0
# 98077  O2996591813         mobile         NaN                   f   NaN
#
#        baths_full  baths_half  garage   price  lot_size  building_size  \
# 0               2         0.0     3.0  570000    7057.0         1756.0
# 1               1         1.0     1.0  470000    5721.0         1030.0
# 2               2         0.0     NaN  830000    5495.0         2503.0
# 3               2         0.0     NaN  400000    5387.0         1248.0
# 4               2         0.0     NaN  659000    5667.0         1897.0
# ...           ...         ...     ...     ...       ...            ...
# 98073           2         1.0     NaN  275000    2614.0         1430.0
# 98074           2         0.0     NaN  899000       NaN            NaN
# 98075           2         0.0     5.0  483500   89734.0         2552.0
# 98076           3         0.0     4.0  345000   87120.0         2040.0
# 98077           2         0.0     NaN  105000  120661.0            0.0
#
#                         line  \
# 0          6375 Converse Ave
# 1              7916 Alix Ave
# 2             1222 E 78th St
# 3             1659 E 70th St
# 4             1364 E 58th Pl
# ...                      ...
# 98073      2365 LA Villa Way
# 98074  13450 Mitchellinda Dr
# 98075         19287 Roxie Ln
# 98076       13143 Tamera Way
# 98077      20034 Parocast Rd
#
#                                            neighborhoods         city  \
# 0                        ['Florence-Graham', 'South LA']  Los Angeles
# 1                        ['Florence-Graham', 'South LA']  Los Angeles
# 2                                           ['South LA']  Los Angeles
# 3                                           ['South LA']  Los Angeles
# 4                                           ['South LA']  Los Angeles
# ...                                                  ...          ...
# 98073  ['Northeast Redding', 'The Villages at Shasta ...      Redding
# 98074                                                NaN      Redding
# 98075                                                NaN      Redding
# 98076                                                NaN      Redding
# 98077                                                NaN      Redding
#
#             county state_code  postal_code  baths
# 0      Los Angeles         CA        90001    2.0
# 1      Los Angeles         CA        90001    1.5
# 2      Los Angeles         CA        90001    2.0
# 3      Los Angeles         CA        90001    2.0
# 4      Los Angeles         CA        90001    2.0
# ...            ...        ...          ...    ...
# 98073       Shasta         CA        96003    2.5
# 98074       Shasta         CA        96003    2.0
# 98075       Shasta         CA        96003    2.0
# 98076       Shasta         CA        96003    3.0
# 98077       Shasta         CA        96003    2.0
#
# [98078 rows x 18 columns]

# %%
housing = housing.fillna(housing.mean()).astype({"year_built": int, "beds": int, "baths_full": int, "baths_half": int, "garage": int,"price": int,
                         "lot_size": int,"building_size": int, "postal_code": str})

# %%
housing = housing[['property_id', 'prop_type', 'year_built', 'is_new_construction', 'beds', 'baths', 'garage'
                  , 'price', 'lot_size', 'building_size', 'line', 'neighborhoods', 'city', 'county', 'state_code',
                  'postal_code', 'baths_full', 'baths_half']]

# %%
housing.head(20)
# Out:
#     property_id      prop_type  year_built is_new_construction  beds  baths  \
# 0   O2889402305   multi_family        1906                   f     3    2.0
# 1   O1305476579  single_family        1913                   f     3    1.5
# 2   O9299703972   multi_family        1938                   f     3    2.0
# 3   O2866856410  single_family        1905                   f     4    2.0
# 4   O2823776981          condo        1912                   f     5    2.0
# 5   O1174561323  single_family        1920                   f     5    5.0
# 6   O1387647983   multi_family        1971                   f     8    4.0
# 7   O1238994138  single_family        1930                   f     2    1.0
# 8   O1296756349   multi_family        1964                   f     3    2.0
# 9   O1223156112  single_family        1937                   f     3    1.5
# 10  O1211901798   multi_family        1948                   f     3    2.0
# 11  O2385237913   multi_family        1930                   f     6    8.0
# 12  O2757890794   multi_family        1930                   f     3    2.0
# 13  O2786660102  single_family        1923                   f     2    1.0
# 14  O1391709970  single_family        1927                   f     3    2.0
# 15  O1302346240  single_family        1925                   f     2    1.0
# 16  O2802796255   multi_family        1908                   f     3    2.0
# 17  O1361822684   multi_family        1961                   f     5    3.0
# 18  O2787181825  single_family        1923                   f     2    1.0
# 19  O2389896155   multi_family        1925                   f     3    2.0
#
#     garage    price  lot_size  building_size                line  \
# 0        3   570000      7057           1756   6375 Converse Ave
# 1        1   470000      5721           1030       7916 Alix Ave
# 2        2   830000      5495           2503      1222 E 78th St
# 3        2   400000      5387           1248      1659 E 70th St
# 4        2   659000      5667           1897      1364 E 58th Pl
# 5        2   477000      6043           2344       7537 Maie Ave
# 6        2   600000      4365           2616     8308 Hooper Ave
# 7        1   420000      1536            784   7708 Stanford Ave
# 8        3   545000      6000           1568  8126 Crockett Blvd
# 9        2   530000      5103           1198       649 E 76th Pl
# 10       2   480000      5103           5103       918 E 76th St
# 11       2  1325000     10206           4264       632 E 82nd St
# 12       2   685000      5549           2226      1213 E 59th Pl
# 13       1   421000      5597            932      1230 E 59th Pl
# 14       2  1010000      5100           1044       910 E 84th Pl
# 15       1   350000      6604            853     7919 Morton Ave
# 16       3   680000      8142           2685      1657 E 59th St
# 17       2   670000      7035            806      1218 E 82nd St
# 18       2   272000      4537            765      1325 E 64th St
# 19       2   686000      5759           1702      1212 E 80th St
#
#                       neighborhoods         city       county state_code  \
# 0   ['Florence-Graham', 'South LA']  Los Angeles  Los Angeles         CA
# 1   ['Florence-Graham', 'South LA']  Los Angeles  Los Angeles         CA
# 2                      ['South LA']  Los Angeles  Los Angeles         CA
# 3                      ['South LA']  Los Angeles  Los Angeles         CA
# 4                      ['South LA']  Los Angeles  Los Angeles         CA
# 5                      ['South LA']  Los Angeles  Los Angeles         CA
# 6                      ['South LA']  Los Angeles  Los Angeles         CA
# 7          ['South LA', 'Florence']  Los Angeles  Los Angeles         CA
# 8                      ['South LA']  Los Angeles  Los Angeles         CA
# 9          ['South LA', 'Florence']  Los Angeles  Los Angeles         CA
# 10         ['South LA', 'Florence']  Los Angeles  Los Angeles         CA
# 11         ['South LA', 'Florence']  Los Angeles  Los Angeles         CA
# 12                     ['South LA']  Los Angeles  Los Angeles         CA
# 13  ['Florence-Graham', 'South LA']  Los Angeles  Los Angeles         CA
# 14         ['South LA', 'Florence']  Los Angeles  Los Angeles         CA
# 15  ['Florence-Graham', 'South LA']  Los Angeles  Los Angeles         CA
# 16                     ['South LA']  Los Angeles  Los Angeles         CA
# 17                     ['South LA']  Los Angeles  Los Angeles         CA
# 18  ['Florence-Graham', 'South LA']  Los Angeles  Los Angeles         CA
# 19                     ['South LA']  Los Angeles  Los Angeles         CA
#
#    postal_code  baths_full  baths_half
# 0        90001           2           0
# 1        90001           1           1
# 2        90001           2           0
# 3        90001           2           0
# 4        90001           2           0
# 5        90001           5           0
# 6        90001           4           0
# 7        90001           1           0
# 8        90001           2           0
# 9        90001           1           1
# 10       90001           2           0
# 11       90001           8           0
# 12       90001           2           0
# 13       90001           1           0
# 14       90001           2           0
# 15       90001           1           0
# 16       90001           2           0
# 17       90001           3           0
# 18       90001           1           0
# 19       90001           2           0

# %%
housing.to_csv("../zip_housing_cleaned.csv")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, explained_variance_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict
from math import sqrt
from math import inf
from math import log
from statistics import median, mean
from sklearn.model_selection import KFold

from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
df = pd.read_csv("sample_final.csv")

# %%
# import tensorflow as tf
# device_name = tf.test.gpu_device_name()
# if device_name != '/device:GPU:0':
#   raise SystemError('GPU device not found')
# print('Found GPU at: {}'.format(device_name))

# %%
# data = pd.read_csv("https://raw.githubusercontent.com/sakuraszy/STATS-170A-Group/main/join_table.csv")
# school = pd.read_csv("https://raw.githubusercontent.com/sakuraszy/STATS-170A-Group/main/Data_final/school_final.csv")
# neighbor = pd.read_csv("https://raw.githubusercontent.com/sakuraszy/STATS-170A-Group/main/Data_in_process/neighbors_count.csv")
# # data.sort_values(by=['price'], ascending=False, inplace = True)
# data = data.select_dtypes(include='number')
# data.insert(0, 'price', data.pop('price'))
# data.dropna(inplace=True)
# data.drop(columns=['population_rank', 'lot_size', 'housing_units', 'year_built'])

# %%
# data = data[data['price'] <= 50000000]
# data = data[data['price'] >= 100000]
# ##data['price'] = data['price'].apply(lambda x: round(log(x), 4))

# %%
##data = data.groupby('zipcode')
##count = 0
##df = pd.DataFrame()
##for name, group in data:
##    truncate_num = int(len(group)*0.05)
##    truncate_len = len(group) - truncate_num
##    group.sort_values(by=['price'])
##    group.truncate(before = truncate_num, after = len(group) - truncate_num)
##    group = group.head(truncate_len)
##    truncate_len -= truncate_num
##    group = group.tail(truncate_len)
##    if(count == 0):
##        df = group
##        count += 1
##    else:
##        df = pd.concat([df, group])
##data.apply(lambda x:x.truncate(before=5, after=5))

# %%
# df = data
# df

# %%
# print(df['price'].mean())

# %%
# school = school.rename(columns={"zip": "zipcode"})
# school

# %%
# neighbor = neighbor.rename(columns={"zip_code": "zipcode"})
# neighbor

# %%
# df = pd.merge(df, school, how = 'left', on = "zipcode", validate="many_to_one")
# df = pd.merge(df, neighbor, how = 'left', on = "zipcode", validate="many_to_one")
# df.set_index('zipcode', inplace=True)
# df.fillna(0, inplace=True)
# df

# %%
# sample_df = df.sample(frac=0.01, random_state=1)

# %%
# from google.colab import files
# sample_df.to_csv('sample_final.csv') 
# files.download('sample_final.csv')

# %%
dc = round(df.corr(), 2)
##dc.drop([0:36])
dc.drop(dc.columns[0:35], axis = 1, inplace = True)
dc
# Out:
#                                                    building_size  rank  \
# zipcode                                                    -0.06  0.08
# price                                                       0.43 -0.36
# population                                                  0.03 -0.02
# population_rank                                             0.10 -0.07
# aland                                                      -0.03  0.12
# median_household_income                                     0.22 -0.63
# average_household_income                                    0.23 -0.62
# per_capita_income                                           0.18 -0.58
# percent_of_households_with_incomes_200000_or_more           0.18 -0.59
# householder_under_25_years                                 -0.02 -0.17
# householder_65_years_and_over                               0.24 -0.51
# hhi_lt_25k                                                 -0.21  0.51
# hhi_200k_or_more                                            0.07 -0.42
# race_and_ethnicity_total                                   -0.11  0.33
# population_density_sq_mi                                   -0.17  0.13
# median_age                                                  0.15 -0.51
# educational_attainment_bachelors                            0.15 -0.62
# educational_attainment_graduate                             0.14 -0.60
# family_poverty_pct                                         -0.19  0.61
# unemployment_pct                                           -0.12  0.48
# housing_units                                              -0.14  0.23
# median_value_of_owner_occupied_units                        0.13 -0.50
# violent_crime_rate                                         -0.13  0.27
# property_crime_rate                                        -0.13  0.21
# postal_code                                                -0.06  0.08
# year_built                                                  0.23 -0.10
# is_single_family                                            0.27  0.02
# is_condo                                                   -0.31 -0.06
# is_multi_family                                             0.07  0.08
# is_new_construction                                         0.04  0.07
# beds                                                        0.62 -0.11
# baths                                                       0.69 -0.15
# baths_beds_ratio                                            0.05 -0.04
# garage                                                      0.41 -0.10
# lot_size                                                    0.03  0.05
# building_size                                               1.00 -0.19
# rank                                                       -0.19  1.00
# rankOf                                                     -0.09  0.61
# rankStars                                                   0.04 -0.17
# rankStatewidePercentage                                     0.05 -0.17
# averageStandardScore                                        0.05 -0.17
# has_elementary                                             -0.10  0.59
# has_middle                                                 -0.13  0.19
# has_high                                                   -0.10  0.41
# ocean_related                                              -0.02 -0.08
# environment_related                                         0.06  0.07
# building_related                                           -0.01  0.23
# community_related                                           0.04  0.10
# positive_comments                                           0.10  0.07
# more_rural                                                  0.05  0.06
# more_urban                                                 -0.06  0.23
# other                                                       0.01  0.24
#
#                                                    rankOf  rankStars  \
# zipcode                                             -0.02      -0.10
# price                                               -0.17       0.10
# population                                           0.01       0.02
# population_rank                                      0.03       0.10
# aland                                                0.06      -0.05
# median_household_income                             -0.31       0.18
# average_household_income                            -0.30       0.17
# per_capita_income                                   -0.26       0.18
# percent_of_households_with_incomes_200000_or_more   -0.28       0.17
# householder_under_25_years                          -0.02       0.13
# householder_65_years_and_over                       -0.23       0.16
# hhi_lt_25k                                           0.27      -0.10
# hhi_200k_or_more                                    -0.07       0.31
# race_and_ethnicity_total                             0.26       0.03
# population_density_sq_mi                             0.09      -0.00
# median_age                                          -0.21       0.21
# educational_attainment_bachelors                    -0.15       0.38
# educational_attainment_graduate                     -0.25       0.24
# family_poverty_pct                                   0.18      -0.31
# unemployment_pct                                     0.12      -0.29
# housing_units                                        0.29       0.16
# median_value_of_owner_occupied_units                -0.20       0.20
# violent_crime_rate                                  -0.01      -0.26
# property_crime_rate                                 -0.06      -0.28
# postal_code                                         -0.02      -0.10
# year_built                                          -0.03       0.06
# is_single_family                                    -0.05      -0.08
# is_condo                                             0.03       0.09
# is_multi_family                                      0.06      -0.02
# is_new_construction                                  0.04      -0.01
# beds                                                -0.06       0.01
# baths                                               -0.06       0.05
# baths_beds_ratio                                     0.02       0.06
# garage                                              -0.07       0.01
# lot_size                                             0.02      -0.02
# building_size                                       -0.09       0.04
# rank                                                 0.61      -0.17
# rankOf                                               1.00       0.65
# rankStars                                            0.65       1.00
# rankStatewidePercentage                              0.65       1.00
# averageStandardScore                                 0.65       0.99
# has_elementary                                       0.94       0.64
# has_middle                                           0.35       0.35
# has_high                                             0.46       0.30
# ocean_related                                        0.05       0.16
# environment_related                                  0.11       0.07
# building_related                                     0.09      -0.07
# community_related                                    0.13       0.06
# positive_comments                                    0.10       0.06
# more_rural                                           0.09       0.07
# more_urban                                           0.22       0.05
# other                                                0.13      -0.07
#
#                                                    rankStatewidePercentage  \
# zipcode                                                              -0.10
# price                                                                 0.11
# population                                                            0.02
# population_rank                                                       0.10
# aland                                                                -0.04
# median_household_income                                               0.18
# average_household_income                                              0.17
# per_capita_income                                                     0.18
# percent_of_households_with_incomes_200000_or_more                     0.17
# householder_under_25_years                                            0.12
# householder_65_years_and_over                                         0.16
# hhi_lt_25k                                                           -0.11
# hhi_200k_or_more                                                      0.31
# race_and_ethnicity_total                                              0.03
# population_density_sq_mi                                             -0.00
# median_age                                                            0.22
# educational_attainment_bachelors                                      0.37
# educational_attainment_graduate                                       0.24
# family_poverty_pct                                                   -0.31
# unemployment_pct                                                     -0.29
# housing_units                                                         0.16
# median_value_of_owner_occupied_units                                  0.20
# violent_crime_rate                                                   -0.26
# property_crime_rate                                                  -0.27
# postal_code                                                          -0.10
# year_built                                                            0.05
# is_single_family                                                     -0.08
# is_condo                                                              0.08
# is_multi_family                                                      -0.01
# is_new_construction                                                  -0.02
# beds                                                                  0.02
# baths                                                                 0.05
# baths_beds_ratio                                                      0.05
# garage                                                                0.00
# lot_size                                                             -0.03
# building_size                                                         0.05
# rank                                                                 -0.17
# rankOf                                                                0.65
# rankStars                                                             1.00
# rankStatewidePercentage                                               1.00
# averageStandardScore                                                  1.00
# has_elementary                                                        0.65
# has_middle                                                            0.35
# has_high                                                              0.30
# ocean_related                                                         0.16
# environment_related                                                   0.08
# building_related                                                     -0.06
# community_related                                                     0.07
# positive_comments                                                     0.06
# more_rural                                                            0.08
# more_urban                                                            0.06
# other                                                                -0.06
#
#                                                    averageStandardScore  \
# zipcode                                                           -0.09
# price                                                              0.12
# population                                                         0.02
# population_rank                                                    0.10
# aland                                                             -0.05
# median_household_income                                            0.19
# average_household_income                                           0.18
# per_capita_income                                                  0.19
# percent_of_households_with_incomes_200000_or_more                  0.18
# householder_under_25_years                                         0.12
# householder_65_years_and_over                                      0.16
# hhi_lt_25k                                                        -0.11
# hhi_200k_or_more                                                   0.32
# race_and_ethnicity_total                                           0.03
# population_density_sq_mi                                          -0.00
# median_age                                                         0.22
# educational_attainment_bachelors                                   0.38
# educational_attainment_graduate                                    0.25
# family_poverty_pct                                                -0.31
# unemployment_pct                                                  -0.28
# housing_units                                                      0.16
# median_value_of_owner_occupied_units                               0.21
# violent_crime_rate                                                -0.25
# property_crime_rate                                               -0.26
# postal_code                                                       -0.09
# year_built                                                         0.05
# is_single_family                                                  -0.07
# is_condo                                                           0.08
# is_multi_family                                                   -0.01
# is_new_construction                                               -0.02
# beds                                                               0.02
# baths                                                              0.06
# baths_beds_ratio                                                   0.05
# garage                                                             0.00
# lot_size                                                          -0.03
# building_size                                                      0.05
# rank                                                              -0.17
# rankOf                                                             0.65
# rankStars                                                          0.99
# rankStatewidePercentage                                            1.00
# averageStandardScore                                               1.00
# has_elementary                                                     0.65
# has_middle                                                         0.34
# has_high                                                           0.29
# ocean_related                                                      0.17
# environment_related                                                0.08
# building_related                                                  -0.06
# community_related                                                  0.07
# positive_comments                                                  0.06
# more_rural                                                         0.08
# more_urban                                                         0.06
# other                                                             -0.06
#
#                                                    has_elementary  has_middle  \
# zipcode                                                      0.00        0.03
# price                                                       -0.18       -0.17
# population                                                  -0.03       -0.04
# population_rank                                              0.04        0.02
# aland                                                        0.06        0.10
# median_household_income                                     -0.32       -0.14
# average_household_income                                    -0.32       -0.17
# per_capita_income                                           -0.29       -0.20
# percent_of_households_with_incomes_200000_or_more           -0.30       -0.16
# householder_under_25_years                                  -0.02       -0.01
# householder_65_years_and_over                               -0.25       -0.09
# hhi_lt_25k                                                   0.29        0.19
# hhi_200k_or_more                                            -0.06        0.01
# race_and_ethnicity_total                                     0.31        0.32
# population_density_sq_mi                                     0.08       -0.04
# median_age                                                  -0.21       -0.10
# educational_attainment_bachelors                            -0.17       -0.14
# educational_attainment_graduate                             -0.27       -0.16
# family_poverty_pct                                           0.20        0.09
# unemployment_pct                                             0.12        0.12
# housing_units                                                0.32        0.28
# median_value_of_owner_occupied_units                        -0.21       -0.15
# violent_crime_rate                                          -0.01       -0.03
# property_crime_rate                                         -0.05       -0.00
# postal_code                                                  0.00        0.03
# year_built                                                  -0.04        0.00
# is_single_family                                            -0.04        0.00
# is_condo                                                     0.02       -0.00
# is_multi_family                                              0.05       -0.00
# is_new_construction                                          0.04       -0.05
# beds                                                        -0.07       -0.07
# baths                                                       -0.07       -0.11
# baths_beds_ratio                                             0.00       -0.06
# garage                                                      -0.08       -0.09
# lot_size                                                     0.01        0.03
# building_size                                               -0.10       -0.13
# rank                                                         0.59        0.19
# rankOf                                                       0.94        0.35
# rankStars                                                    0.64        0.35
# rankStatewidePercentage                                      0.65        0.35
# averageStandardScore                                         0.65        0.34
# has_elementary                                               1.00        0.46
# has_middle                                                   0.46        1.00
# has_high                                                     0.60        0.36
# ocean_related                                                0.09        0.12
# environment_related                                          0.14        0.18
# building_related                                             0.12        0.03
# community_related                                            0.16        0.19
# positive_comments                                            0.12        0.10
# more_rural                                                   0.14        0.15
# more_urban                                                   0.24        0.12
# other                                                        0.15        0.12
#
#                                                    has_high  ocean_related  \
# zipcode                                                0.06          -0.04
# price                                                 -0.19           0.16
# population                                            -0.04          -0.10
# population_rank                                        0.01           0.17
# aland                                                  0.04          -0.03
# median_household_income                               -0.28           0.00
# average_household_income                              -0.32           0.04
# per_capita_income                                     -0.34           0.09
# percent_of_households_with_incomes_200000_or_more     -0.29           0.05
# householder_under_25_years                            -0.04          -0.01
# householder_65_years_and_over                         -0.22           0.06
# hhi_lt_25k                                             0.28           0.07
# hhi_200k_or_more                                      -0.06           0.12
# race_and_ethnicity_total                               0.39           0.05
# population_density_sq_mi                              -0.03          -0.03
# median_age                                            -0.21           0.09
# educational_attainment_bachelors                      -0.27           0.12
# educational_attainment_graduate                       -0.32           0.06
# family_poverty_pct                                     0.22          -0.07
# unemployment_pct                                       0.18          -0.09
# housing_units                                          0.34           0.17
# median_value_of_owner_occupied_units                  -0.27           0.14
# violent_crime_rate                                     0.05          -0.02
# property_crime_rate                                   -0.03           0.01
# postal_code                                            0.06          -0.04
# year_built                                            -0.01           0.02
# is_single_family                                       0.04          -0.06
# is_condo                                              -0.06           0.07
# is_multi_family                                        0.04          -0.01
# is_new_construction                                    0.04           0.06
# beds                                                  -0.04          -0.05
# baths                                                 -0.11          -0.02
# baths_beds_ratio                                      -0.11           0.01
# garage                                                -0.07          -0.01
# lot_size                                               0.02          -0.01
# building_size                                         -0.10          -0.02
# rank                                                   0.41          -0.08
# rankOf                                                 0.46           0.05
# rankStars                                              0.30           0.16
# rankStatewidePercentage                                0.30           0.16
# averageStandardScore                                   0.29           0.17
# has_elementary                                         0.60           0.09
# has_middle                                             0.36           0.12
# has_high                                               1.00           0.07
# ocean_related                                          0.07           1.00
# environment_related                                    0.20           0.10
# building_related                                       0.18           0.03
# community_related                                      0.21           0.15
# positive_comments                                      0.15           0.16
# more_rural                                             0.19           0.14
# more_urban                                             0.26           0.25
# other                                                  0.20           0.07
#
#                                                    environment_related  \
# zipcode                                                           0.22
# price                                                            -0.21
# population                                                       -0.31
# population_rank                                                   0.36
# aland                                                             0.30
# median_household_income                                          -0.02
# average_household_income                                         -0.08
# per_capita_income                                                -0.16
# percent_of_households_with_incomes_200000_or_more                -0.10
# householder_under_25_years                                       -0.04
# householder_65_years_and_over                                     0.05
# hhi_lt_25k                                                        0.03
# hhi_200k_or_more                                                  0.08
# race_and_ethnicity_total                                          0.34
# population_density_sq_mi                                         -0.41
# median_age                                                        0.07
# educational_attainment_bachelors                                 -0.18
# educational_attainment_graduate                                  -0.22
# family_poverty_pct                                               -0.11
# unemployment_pct                                                  0.04
# housing_units                                                     0.32
# median_value_of_owner_occupied_units                             -0.25
# violent_crime_rate                                               -0.16
# property_crime_rate                                              -0.06
# postal_code                                                       0.22
# year_built                                                        0.21
# is_single_family                                                  0.15
# is_condo                                                         -0.12
# is_multi_family                                                  -0.11
# is_new_construction                                              -0.01
# beds                                                              0.04
# baths                                                             0.00
# baths_beds_ratio                                                 -0.07
# garage                                                            0.11
# lot_size                                                          0.00
# building_size                                                     0.06
# rank                                                              0.07
# rankOf                                                            0.11
# rankStars                                                         0.07
# rankStatewidePercentage                                           0.08
# averageStandardScore                                              0.08
# has_elementary                                                    0.14
# has_middle                                                        0.18
# has_high                                                          0.20
# ocean_related                                                     0.10
# environment_related                                               1.00
# building_related                                                  0.21
# community_related                                                 0.96
# positive_comments                                                 0.86
# more_rural                                                        0.78
# more_urban                                                        0.63
# other                                                             0.76
#
#                                                    building_related  \
# zipcode                                                       -0.15
# price                                                         -0.02
# population                                                     0.15
# population_rank                                                0.00
# aland                                                          0.09
# median_household_income                                       -0.19
# average_household_income                                      -0.15
# per_capita_income                                             -0.11
# percent_of_households_with_incomes_200000_or_more             -0.13
# householder_under_25_years                                    -0.08
# householder_65_years_and_over                                 -0.17
# hhi_lt_25k                                                     0.22
# hhi_200k_or_more                                              -0.07
# race_and_ethnicity_total                                       0.09
# population_density_sq_mi                                       0.03
# median_age                                                    -0.02
# educational_attainment_bachelors                              -0.12
# educational_attainment_graduate                               -0.10
# family_poverty_pct                                             0.18
# unemployment_pct                                               0.11
# housing_units                                                  0.11
# median_value_of_owner_occupied_units                          -0.07
# violent_crime_rate                                             0.10
# property_crime_rate                                            0.06
# postal_code                                                   -0.15
# year_built                                                    -0.16
# is_single_family                                               0.02
# is_condo                                                      -0.05
# is_multi_family                                                0.08
# is_new_construction                                            0.03
# beds                                                          -0.04
# baths                                                         -0.01
# baths_beds_ratio                                               0.01
# garage                                                        -0.09
# lot_size                                                      -0.03
# building_size                                                 -0.01
# rank                                                           0.23
# rankOf                                                         0.09
# rankStars                                                     -0.07
# rankStatewidePercentage                                       -0.06
# averageStandardScore                                          -0.06
# has_elementary                                                 0.12
# has_middle                                                     0.03
# has_high                                                       0.18
# ocean_related                                                  0.03
# environment_related                                            0.21
# building_related                                               1.00
# community_related                                              0.25
# positive_comments                                              0.39
# more_rural                                                     0.26
# more_urban                                                     0.36
# other                                                          0.27
#
#                                                    community_related  \
# zipcode                                                         0.20
# price                                                          -0.21
# population                                                     -0.26
# population_rank                                                 0.32
# aland                                                           0.25
# median_household_income                                        -0.05
# average_household_income                                       -0.11
# per_capita_income                                              -0.19
# percent_of_households_with_incomes_200000_or_more              -0.13
# householder_under_25_years                                     -0.06
# householder_65_years_and_over                                   0.01
# hhi_lt_25k                                                      0.09
# hhi_200k_or_more                                                0.07
# race_and_ethnicity_total                                        0.37
# population_density_sq_mi                                       -0.36
# median_age                                                      0.03
# educational_attainment_bachelors                               -0.19
# educational_attainment_graduate                                -0.24
# family_poverty_pct                                             -0.06
# unemployment_pct                                                0.05
# housing_units                                                   0.34
# median_value_of_owner_occupied_units                           -0.25
# violent_crime_rate                                             -0.14
# property_crime_rate                                            -0.05
# postal_code                                                     0.20
# year_built                                                      0.20
# is_single_family                                                0.15
# is_condo                                                       -0.13
# is_multi_family                                                -0.07
# is_new_construction                                            -0.01
# beds                                                            0.05
# baths                                                          -0.00
# baths_beds_ratio                                               -0.08
# garage                                                          0.10
# lot_size                                                       -0.00
# building_size                                                   0.04
# rank                                                            0.10
# rankOf                                                          0.13
# rankStars                                                       0.06
# rankStatewidePercentage                                         0.07
# averageStandardScore                                            0.07
# has_elementary                                                  0.16
# has_middle                                                      0.19
# has_high                                                        0.21
# ocean_related                                                   0.15
# environment_related                                             0.96
# building_related                                                0.25
# community_related                                               1.00
# positive_comments                                               0.84
# more_rural                                                      0.72
# more_urban                                                      0.68
# other                                                           0.75
#
#                                                    positive_comments  \
# zipcode                                                         0.14
# price                                                          -0.12
# population                                                     -0.22
# population_rank                                                 0.37
# aland                                                           0.32
# median_household_income                                        -0.01
# average_household_income                                       -0.02
# per_capita_income                                              -0.06
# percent_of_households_with_incomes_200000_or_more              -0.04
# householder_under_25_years                                     -0.08
# householder_65_years_and_over                                   0.07
# hhi_lt_25k                                                      0.04
# hhi_200k_or_more                                                0.09
# race_and_ethnicity_total                                        0.21
# population_density_sq_mi                                       -0.40
# median_age                                                      0.10
# educational_attainment_bachelors                               -0.12
# educational_attainment_graduate                                -0.13
# family_poverty_pct                                             -0.08
# unemployment_pct                                                0.04
# housing_units                                                   0.23
# median_value_of_owner_occupied_units                           -0.16
# violent_crime_rate                                             -0.11
# property_crime_rate                                            -0.02
# postal_code                                                     0.14
# year_built                                                      0.13
# is_single_family                                                0.14
# is_condo                                                       -0.11
# is_multi_family                                                -0.09
# is_new_construction                                            -0.02
# beds                                                            0.02
# baths                                                           0.02
# baths_beds_ratio                                               -0.02
# garage                                                          0.07
# lot_size                                                       -0.03
# building_size                                                   0.10
# rank                                                            0.07
# rankOf                                                          0.10
# rankStars                                                       0.06
# rankStatewidePercentage                                         0.06
# averageStandardScore                                            0.06
# has_elementary                                                  0.12
# has_middle                                                      0.10
# has_high                                                        0.15
# ocean_related                                                   0.16
# environment_related                                             0.86
# building_related                                                0.39
# community_related                                               0.84
# positive_comments                                               1.00
# more_rural                                                      0.73
# more_urban                                                      0.60
# other                                                           0.73
#
#                                                    more_rural  more_urban  \
# zipcode                                                  0.09        0.08
# price                                                   -0.12       -0.06
# population                                              -0.17        0.02
# population_rank                                          0.36        0.16
# aland                                                    0.27        0.06
# median_household_income                                 -0.01       -0.19
# average_household_income                                -0.04       -0.18
# per_capita_income                                       -0.08       -0.13
# percent_of_households_with_incomes_200000_or_more       -0.05       -0.18
# householder_under_25_years                              -0.04       -0.05
# householder_65_years_and_over                            0.03       -0.16
# hhi_lt_25k                                               0.07        0.32
# hhi_200k_or_more                                         0.14        0.07
# race_and_ethnicity_total                                 0.29        0.37
# population_density_sq_mi                                -0.34        0.02
# median_age                                               0.09       -0.08
# educational_attainment_bachelors                        -0.06       -0.08
# educational_attainment_graduate                         -0.12       -0.18
# family_poverty_pct                                      -0.11        0.08
# unemployment_pct                                         0.01        0.02
# housing_units                                            0.32        0.47
# median_value_of_owner_occupied_units                    -0.12       -0.10
# violent_crime_rate                                      -0.15        0.01
# property_crime_rate                                     -0.08        0.04
# postal_code                                              0.09        0.08
# year_built                                               0.13       -0.04
# is_single_family                                         0.09       -0.01
# is_condo                                                -0.06       -0.00
# is_multi_family                                         -0.07        0.04
# is_new_construction                                     -0.01        0.02
# beds                                                    -0.01       -0.06
# baths                                                    0.00       -0.05
# baths_beds_ratio                                        -0.01        0.00
# garage                                                   0.07       -0.07
# lot_size                                                -0.01        0.01
# building_size                                            0.05       -0.06
# rank                                                     0.06        0.23
# rankOf                                                   0.09        0.22
# rankStars                                                0.07        0.05
# rankStatewidePercentage                                  0.08        0.06
# averageStandardScore                                     0.08        0.06
# has_elementary                                           0.14        0.24
# has_middle                                               0.15        0.12
# has_high                                                 0.19        0.26
# ocean_related                                            0.14        0.25
# environment_related                                      0.78        0.63
# building_related                                         0.26        0.36
# community_related                                        0.72        0.68
# positive_comments                                        0.73        0.60
# more_rural                                               1.00        0.54
# more_urban                                               0.54        1.00
# other                                                    0.63        0.59
#
#                                                    other
# zipcode                                             0.16
# price                                              -0.27
# population                                         -0.22
# population_rank                                     0.25
# aland                                               0.28
# median_household_income                            -0.26
# average_household_income                           -0.28
# per_capita_income                                  -0.32
# percent_of_households_with_incomes_200000_or_more  -0.29
# householder_under_25_years                         -0.18
# householder_65_years_and_over                      -0.15
# hhi_lt_25k                                          0.21
# hhi_200k_or_more                                   -0.16
# race_and_ethnicity_total                            0.28
# population_density_sq_mi                           -0.32
# median_age                                         -0.15
# educational_attainment_bachelors                   -0.37
# educational_attainment_graduate                    -0.35
# family_poverty_pct                                  0.20
# unemployment_pct                                    0.27
# housing_units                                       0.21
# median_value_of_owner_occupied_units               -0.38
# violent_crime_rate                                 -0.00
# property_crime_rate                                 0.10
# postal_code                                         0.16
# year_built                                          0.10
# is_single_family                                    0.19
# is_condo                                           -0.18
# is_multi_family                                    -0.06
# is_new_construction                                -0.03
# beds                                                0.01
# baths                                              -0.05
# baths_beds_ratio                                   -0.10
# garage                                              0.01
# lot_size                                           -0.02
# building_size                                       0.01
# rank                                                0.24
# rankOf                                              0.13
# rankStars                                          -0.07
# rankStatewidePercentage                            -0.06
# averageStandardScore                               -0.06
# has_elementary                                      0.15
# has_middle                                          0.12
# has_high                                            0.20
# ocean_related                                       0.07
# environment_related                                 0.76
# building_related                                    0.27
# community_related                                   0.75
# positive_comments                                   0.73
# more_rural                                          0.63
# more_urban                                          0.59
# other                                               1.00

# %%
fig, ax = plt.subplots(figsize=(25,5))
sns.set(font_scale=3)
sns.heatmap(dc[4:7], annot = True, 
            cmap=plt.get_cmap('coolwarm'), vmin = -1, vmax = 1, annot_kws={"fontsize":25}).figure.axes[-1].yaxis.label.set_size(450)
fig.suptitle('Correlation Plot for Essential Features', fontsize=40)
ax.set_yticklabels(ax.get_yticklabels(), fontsize = 25)
ax.set_xticklabels(ax.get_xticklabels(), rotation="30", horizontalalignment='right', fontsize = 25)
# Out:
# [Text(0.5, 0, 'building_size'),
#  Text(1.5, 0, 'rank'),
#  Text(2.5, 0, 'rankOf'),
#  Text(3.5, 0, 'rankStars'),
#  Text(4.5, 0, 'rankStatewidePercentage'),
#  Text(5.5, 0, 'averageStandardScore'),
#  Text(6.5, 0, 'has_elementary'),
#  Text(7.5, 0, 'has_middle'),
#  Text(8.5, 0, 'has_high'),
#  Text(9.5, 0, 'ocean_related'),
#  Text(10.5, 0, 'environment_related'),
#  Text(11.5, 0, 'building_related'),
#  Text(12.5, 0, 'community_related'),
#  Text(13.5, 0, 'positive_comments'),
#  Text(14.5, 0, 'more_rural'),
#  Text(15.5, 0, 'more_urban'),
#  Text(16.5, 0, 'other')]

# %%
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, shuffle = True)
log_y_train = np.log(y_train)
log_y_test = np.log(y_test)
log_y = np.log(y)

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
def inv_normalize_price(feature_normalized):
    mu = log_y.mean()
    sd = log_y.std()
    return sd*feature_normalized + mu

# %%
print("Linear Regression\n")
regr = LinearRegression()
kfold = KFold(n_splits=5)
y_pred = cross_val_predict(regr, X, log_y, cv=kfold)
test_error = sqrt(mean_squared_error(y, np.exp(y_pred)))
print(test_error)
# scores = cross_validate(regr, X, y, cv=kfold,
#                         scoring=('r2', 'neg_root_mean_squared_error'),
#                         return_train_score=True)
# print('train rmse is: ' + str(-1*mean(scores['train_neg_root_mean_squared_error'])))
# print('test rmse is: ' + str(-1*mean(scores['test_neg_root_mean_squared_error'])))
# print('R-square is: ' + str(mean(scores['test_r2'])))
#regr.fit(X_train, log_y_train)
#print(regr.score(X_test, log_y_test))
# Out:
# Linear Regression
#
# 48.92467256746259

# %%
#train_error = sqrt(mean_squared_error(y_train, np.exp(regr.predict(X_train))))
#print(train_error)

# %%
#test_error = sqrt(mean_squared_error(y_test, np.exp(regr.predict(X_test))))
#print(test_error)

# %%
# plt.figure(figsize=(15,10))
# plt.scatter(y_test, y_test-np.exp(regr.predict(X_test)))
# plt.title('Residuals VS Fitted Values', fontsize = 25)
# plt.xlabel('Fitted Values(Price in $)', fontsize = 20)
# plt.ylabel('Residuals', fontsize = 20)
# plt.ticklabel_format(useOffset=False, style='plain')
# plt.show()

# %%
# lr_cv = LinearRegression()
# kfold = KFold(n_splits=5, shuffle = True)
# lr_cv_scores = cross_val_score(lr_cv, X, y, cv=kfold)
# print(lr_cv_scores)
# print('cv_scores mean {}'.format(np.mean(lr_cv_scores)))

# %%
print("KNN\n")
neighbors = np.arange(1, 11)
train_rmse = np.empty(len(neighbors))
test_rmse = np.empty(len(neighbors))
r_square_list = np.empty(len(neighbors))
best_k = 0
best_difference = inf
  
# with tf.device('/device:GPU:0'):
for i, k in enumerate(neighbors):
  knn = KNeighborsRegressor(n_neighbors=k)
  kfold = KFold(n_splits=5, shuffle = True)
  scores = cross_validate(knn, X, y, cv=kfold,
                          scoring=('r2', 'neg_root_mean_squared_error'),
                          return_train_score=True)
  print(k)
  print('train rmse is: ' + str(-1*mean(scores['train_neg_root_mean_squared_error'])))
  train_rmse[i] = -1*mean(scores['train_neg_root_mean_squared_error'])
  print('test rmse is: ' + str(-1*mean(scores['test_neg_root_mean_squared_error'])))
  test_rmse[i] = -1*mean(scores['test_neg_root_mean_squared_error'])
  print('R-square is: ' + str(mean(scores['test_r2'])))
  r_square_list[i] = mean(scores['test_r2'])
      #knn.fit(X_train, y_train)
        
      # Compute traning and test data accuracy
#       train_pred = knn.predict(X_train)
#       test_pred = knn.predict(X_test)
#       train_error = sqrt(mean_squared_error(y_train, train_pred))
#       test_error = sqrt(mean_squared_error(y_test,test_pred))
#       for_test_error_hist = y_test-test_pred
#       print(np.median(for_test_error_hist))
#       print(max(for_test_error_hist))
#       if test_error-train_error < best_difference and test_error-train_error > 0:
#         best_difference = test_error-train_error
#         best_k = k
        
#         plt.figure(figsize=(15,15))
#         plt.hist(for_test_error_hist, range=[-800000 , 800000])
      
#       train_rmse[i] = train_error
#       test_rmse[i] = test_error
#       r_s = knn.score(X_test, y_test)
#       r_square_list[i] = r_s
#       print(k)
#       print('R-square is: ' + str(r_s))
#       print('Adjusted R-square is ' + str(1-(1-r_s)*(len(X_test)/(len(X_test)-30))))
#       print('Explained variance: ' + str(explained_variance_score(y_test, test_pred)))
#       print('train rmse is: ' + str(train_error))
#       print('test rmse is: ' + str(test_error))

# print("Best K is " + str(best_k))
# Out:
# KNN
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-23a87d3e4248> in <module>
#       7 best_difference = inf
#       8
# ----> 9 with tf.device('/device:GPU:0'):
#      10   for i, k in enumerate(neighbors):
#      11       knn = KNeighborsRegressor(n_neighbors=k)
#
# NameError: name 'tf' is not defined

# %%
knn_cv = KNeighborsRegressor(n_neighbors=3)
kfold = KFold(n_splits=5, shuffle = True)
cv_scores = cross_val_score(knn_cv, X, y, cv=kfold)
print(cv_scores)
print('cv_scores mean{}'.format(np.mean(cv_scores)))

# %%
# X = df.iloc[:,lambda df: [4, 7]].values
# y = df.iloc[:, 0].values
# print(X)

# %%
fig, ax = plt.subplots(figsize=(15,8))
plt.plot(neighbors, test_rmse, label = 'Testing dataset RMSE')
plt.plot(neighbors, train_rmse, label = 'Training dataset RMSE')
plt.title('RMSE VS K nearest neighbors', fontsize = 25)
  
plt.legend(fontsize = 20)
plt.xlabel('n_neighbors', fontsize = 25)
plt.ylabel('RMSE', fontsize = 25)
plt.xticks(fontsize = 25)
ax.set_yticklabels(['-1', '0', '100,000', '200,000', '300,000'], fontsize = 25)
##plt.ticklabel_format(useOffset=False, style='plain')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(neighbors, r_square_list, label = 'R-sqaure plot')
plt.title('R-squared plot', fontsize = 25)
  
plt.legend()
plt.xlabel('n_neighbors')
plt.ylabel('R-square')
plt.show()

# %%
rf = RandomForestRegressor(n_estimators = 50, bootstrap=True, max_depth=80, min_samples_leaf=2, min_samples_split=5)
rf.fit(X_train, y_train)

# %%
for_his = np.absolute(y_test - rf.predict(X_test))
fig, ax = plt.subplots(figsize=(20,8))
plt.title('Distribution of Residuals(Random Forest)')
plt.hist(for_his, range = [0, 600000], weights=np.ones(len(for_his)) / len(for_his))
ax.set_xticklabels([ '-1', '0', '100,000', '200,000', '300,000', '400,000', '500,000', '600,000'], fontsize = 25)
plt.show()

# %%
print("Random Forest\n")
rf_n = [1, 10, 20, 50, 100]
rf_train_rmse = []
rf_test_rmse = []
best_n = 0
best_test_rmse = inf

with tf.device('/device:GPU:0'):
  for n in rf_n:
    rf = RandomForestRegressor(n_estimators = n)
    kfold = KFold(n_splits=5, shuffle = True)
    scores = cross_validate(rf, X, y, cv=kfold,
                              scoring=('r2', 'neg_root_mean_squared_error'),
                              return_train_score=True)
    print(n)
    print('train rmse is: ' + str(-1*mean(scores['train_neg_root_mean_squared_error'])))
    rf_train_rmse.append(-1*mean(scores['train_neg_root_mean_squared_error']))
    print('test rmse is: ' + str(-1*mean(scores['test_neg_root_mean_squared_error'])))
    rf_test_rmse.append(-1*mean(scores['test_neg_root_mean_squared_error']))
    print('R-square is: ' + str(mean(scores['test_r2'])))
    if(-1*mean(scores['test_neg_root_mean_squared_error']) < best_test_rmse):
      best_test_rmse = -1*mean(scores['test_neg_root_mean_squared_error'])
      best_n = n
    # r_square_list[i] = mean(scores['test_r2'])
    # rf.fit(X_train, y_train)
    # print("Score for " + str(n) + " is: " + str(rf.score(X_test, y_test)))
    # train_error = sqrt(mean_squared_error(y_train, rf.predict(X_train)))
    # rf_train_rmse.append(train_error)
    # print("Training error for " + str(n) + " is: " + str(train_error))
    # test_error = sqrt(mean_squared_error(y_test, rf.predict(X_test)))
    # rf_test_rmse.append(test_error)
    # print("Testing error for " + str(n) + " is: " + str(test_error))

# %%
fig, ax = plt.subplots(figsize=(15,8))
plt.plot(rf_n, rf_test_rmse, label = 'Testing dataset RMSE')
plt.plot(rf_n, rf_train_rmse, label = 'Training dataset RMSE')
plt.title('RMSE VS n_estimators', fontsize = 25)
  
plt.legend(fontsize = 20)
plt.xlabel('n_estimators', fontsize = 25)
plt.ylabel('RMSE', fontsize = 25)
plt.ylim(0, 400000)
plt.xticks([1, 10, 20, 50, 100], fontsize = 25)
##plt.yticks([200000, 400000, 600000, 800000, 1000000, 1200000], fontsize = 18)
ax.set_yticklabels([ '0', '100,000', '150,000', '200,000', '250,000', '300,000'], fontsize = 25)
##plt.ticklabel_format(useOffset=False, style='plain')
plt.show()

# %%
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]

random_grid = {'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

rf = RandomForestRegressor(n_estimators=50)
rf_best = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 30, cv = 5, verbose=2, random_state=42, n_jobs = -1)
rf_best.fit(X_train, y_train)
print("Score is: " + str(rf_best.score(X_test, y_test)))
train_error = sqrt(mean_squared_error(y_train, rf_best.predict(X_train)))
##rf_train_rmse.append(train_error)
print("Training error is: " + str(train_error))
test_error = sqrt(mean_squared_error(y_test, rf_best.predict(X_test)))
##rf_test_rmse.append(test_error)
print("Testing error for is: " + str(test_error))

# %%
rf_best.best_params_

# %%
rf = RandomForestRegressor(n_estimators = 50, bootstrap=rf_best.best_params_['bootstrap'], max_depth=rf_best.best_params_['max_depth'], min_samples_leaf=rf_best.best_params_['min_samples_leaf'], min_samples_split=rf_best.best_params_['min_samples_split'])
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
pd.DataFrame({'Variable':df.iloc[:, 1:].columns,
              'Importance':rf.feature_importances_}).sort_values('Importance', ascending=False)

# %%
# rf = RandomForestRegressor(n_estimators = 50)
# rf.fit(X_train, y_train)
# y_pred = rf.predict(X_test)

# %%
# plt.figure(figsize=(15,10))
# plt.scatter(y_pred, y_test-y_pred)
# plt.title('Residuals VS Fitted Values', fontsize = 25)
# plt.xlabel('Fitted Values(Price in $)', fontsize = 20)
# plt.ylabel('Residuals', fontsize = 20)
# plt.xlim(0, 10000000)
# plt.ylim(-5000000, 5000000)
# plt.ticklabel_format(useOffset=False, style='plain')
# plt.show()

# %%
# rf_cv = RandomForestRegressor(n_estimators = 20)
# kfold = KFold(n_splits=5, shuffle = True)
# rf_cv_scores = cross_val_score(rf_cv, X, y, cv=kfold)
# print(rf_cv_scores)
# print('cv_scores mean{}'.format(np.mean(rf_cv_scores)))

# %%
print('\n')
print('ANN')
test_errors=[]
with tf.device('/device:GPU:0'):
  for layers in [50,60,70]:
    NNregr=MLPRegressor(hidden_layer_sizes=(layers, 7), max_iter=1000)
    NNregr.n_layers_=7
    NNregr.fit(X_train, y_train)
    train_error = sqrt(mean_squared_error(y_train, NNregr.predict(X_train)))
    print('\n')
    print("Hidden layers for " + str(layers) + " is: " + str(NNregr.n_layers_))
    print("Training error for " + str(layers) + " is: " + str(train_error))
    test_error = sqrt(mean_squared_error(y_test, NNregr.predict(X_test)))
    test_errors.append(test_error)
    print("Testing error for " + str(layers) + " is: " + str(test_error))
    score = NNregr.score(X_test, y_test)
    print("Score for " + str(layers) + " is: " + str(score))

# %%
test_errors

# %%
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.wrappers.scikit_learn import KerasRegressor
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import KFold
# #load dataset
# #split into input (X) and output (Y) variables
# #define base model
# #def baseline_model():
# # create model
# model = Sequential()
# model.add(Dense(50, input_dim=50, kernel_initializer='normal', activation='relu'))
# model.add(Dense(25, input_dim=50, kernel_initializer='normal', activation='relu'))
# model.add(Dense(1, kernel_initializer='normal'))
# # Compile model
# model.compile(loss='mean_squared_error', optimizer='adam')
# #return model
# #evaluate model
# #estimator = KerasRegressor(build_fn=baseline_model, epochs=100, batch_size=5, verbose=0)
# with tf.device('/device:GPU:0'):
#   model.fit(X_train, y_train, epochs=50, batch_size=5)
# test_error = sqrt(mean_squared_error(y_test, model.predict(X_test)))
# print(test_error)
# #kfold = KFold(n_splits=10)
# #results = cross_val_score(estimator, X_train, y_train, cv=kfold)
# #print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
